# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean() * 100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']

# %%
X_test.tail()
# Out:
#       Age     Fare  Age_imputed
# 89   24.0   8.0500         24.0
# 80   22.0   9.0000         22.0
# 846   NaN  69.5500          NaN
# 870  26.0   7.8958         26.0
# 251  29.0  10.4625         29.0

# %%
X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\3090101260.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\series.py:1310, in Series.__setitem__(self, key, value)
#    1309 try:
# -> 1310     self._set_with_engine(key, value, warn=warn)
#    1311 except KeyError:
#    1312     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1313     #  key that is not present in self.index.
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\series.py:1382, in Series._set_with_engine(self, key, value, warn)
#    1381 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1382     loc = self.index.get_loc(key)
#    1384     # this is equivalent to self._values[key] = value
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6069 if not is_scalar(key):
#    6070     # if key is not a scalar, directly raise an error (the code below
#    6071     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072     raise InvalidIndexError(key)
#
# InvalidIndexError: 30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
#       2 X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\series.py:1363, in Series.__setitem__(self, key, value)
#    1353 if (
#    1354     is_list_like(value)
#    1355     and len(value) != len(self)
#    (...)   1360     #  _where call below
#    1361     # GH#44265
#    1362     indexer = key.nonzero()[0]
# -> 1363     self._set_values(indexer, value)
#    1364     return
#    1366 # otherwise with listlike other we interpret series[mask] = other
#    1367 #  as series[mask] = other[mask]
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\series.py:1431, in Series._set_values(self, key, value, warn)
#    1428 if isinstance(key, (Index, Series)):
#    1429     key = key._values
# -> 1431 self._mgr = self._mgr.setitem(indexer=key, value=value, warn=warn)
#    1432 self._maybe_update_cacher()
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\internals\managers.py:434, in BaseBlockManager.setitem(self, indexer, value, warn)
#     430     # No need to split if we either set all columns or on a single block
#     431     # manager
#     432     self = self.copy()
# --> 434 return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\internals\blocks.py:1469, in Block.setitem(self, indexer, value, using_cow)
#    1466     values = values.T
#    1468 # length checking
# -> 1469 check_setitem_lengths(indexer, value, values)
#    1471 if self.dtype != _dtype_obj:
#    1472     # GH48933: extract_array would convert a pd.Series value to np.ndarray
#    1473     value = extract_array(value, extract_numpy=True)
#
# File ~\.conda\envs\ml\Lib\site-packages\pandas\core\indexers\utils.py:166, in check_setitem_lengths(indexer, value, values)
#     160         indexer = np.array(indexer)
#     161     if not (
#     162         isinstance(indexer, np.ndarray)
#     163         and indexer.dtype == np.bool_
#     164         and indexer.sum() == len(value)
#     165     ):
# --> 166         raise ValueError(
#     167             "cannot set using a list-like indexer "
#     168             "with a different length than the value"
#     169         )
#     170 if not len(indexer):
#     171     no_op = True
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# Out:
# array([52.  , 29.  , 21.  ,  9.  , 33.  , 30.  , 40.5 , 19.  , 48.  ,
#        19.  , 36.  , 58.  , 29.  , 30.  , 54.  , 20.  , 20.  ,  7.  ,
#        16.  , 32.  , 25.  , 20.  , 14.5 , 24.  , 29.  ,  2.  , 28.5 ,
#        23.  , 40.  , 29.  , 26.  , 17.  , 21.  , 28.  ,  2.  ,  5.  ,
#        24.  ,  9.  , 23.  , 37.  , 36.  , 24.  , 19.  , 44.  , 38.  ,
#        29.  , 48.  , 26.  , 16.  , 39.  ,  9.  , 22.  , 70.5 , 32.  ,
#        20.  ,  3.  , 40.5 , 31.  , 33.  , 66.  , 24.  , 34.  , 34.  ,
#        19.  , 39.  , 16.  , 19.  , 56.  , 27.  , 31.  , 18.  , 36.  ,
#        32.  , 20.  , 48.  , 24.  ,  3.  , 25.  , 26.  , 21.  , 24.  ,
#        29.  ,  6.  , 36.  , 18.  , 24.  , 40.  , 47.  , 18.  , 18.  ,
#        34.  , 21.  ,  8.  , 52.  , 29.  , 24.  , 18.  , 54.  , 34.  ,
#        34.  , 33.  , 48.  , 50.  , 26.  , 29.  , 34.  , 39.  , 31.  ,
#        33.  , 22.  , 22.  , 14.  , 31.  , 58.  , 28.  , 60.  , 41.  ,
#        32.  , 24.  ,  0.83, 22.  , 34.  , 28.  , 63.  ,  5.  ,  7.  ,
#        34.  , 42.  , 42.  , 25.  , 25.  , 36.  , 35.  ,  3.  , 23.  ,
#         2.  , 29.  , 16.  ,  4.  , 30.  , 32.  , 21.  , 27.  , 36.  ,
#        36.5 , 27.  , 21.  , 65.  ])

# %%
X_train['Age'].isnull().sum()
# Out:
# np.int64(148)

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         62.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         23.5
# 168   NaN   25.9250         28.0
#
# [712 rows x 3 columns]

# %%
sns.kdeplot(X_train['Age'], label='Original')
sns.kdeplot(X_train['Age_imputed'], label='Imputed')

plt.legend()
plt.show()

# %%
print('Original variable variance: ', X_train['Age'].var())
print('Variance after random imputation: ', X_train['Age_imputed'].var())
# Out:
# Original variable variance:  204.3495133904614
# Variance after random imputation:  209.0387067492772

# %%
X_train[['Fare', 'Age', 'Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    71.227460
# Age            71.512440  204.349513   204.349513
# Age_imputed    71.227460  204.349513   209.038707

# %%
X_train[['Age', 'Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))

# at production level , we need to insure that for same input we get same output and for that we use observation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sampled_value = X_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))
#
# NameError: name 'observation' is not defined

# %%
data = pd.read_csv('house-train.csv',usecols=['GarageQual','FireplaceQu', 'SalePrice'])

# %%
data.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
data.isnull().mean() * 100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
X = data
y = data['SalePrice']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train['GarageQual_imputed'] = X_train['GarageQual']
X_test['GarageQual_imputed'] = X_test['GarageQual']

X_train['FireplaceQu_imputed'] = X_train['FireplaceQu']
X_test['FireplaceQu_imputed'] = X_test['FireplaceQu']

# %%
X_train.sample(5)
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imputed FireplaceQu_imputed
# 713          NaN         TA     129000                 TA                 NaN
# 1269         NaN         TA     144000                 TA                 NaN
# 31           NaN         TA     149350                 TA                 NaN
# 227          NaN         TA     106000                 TA                 NaN
# 1434          Gd         TA     160000                 TA                  Gd

# %%
X_train['GarageQual_imputed'][X_train['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
X_test['GarageQual_imputed'][X_test['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values

X_train['FireplaceQu_imputed'][X_train['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_train['FireplaceQu'].isnull().sum()).values
X_test['FireplaceQu_imputed'][X_test['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_test['FireplaceQu'].isnull().sum()).values
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_train['GarageQual_imputed'][X_train['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['GarageQual_imputed'][X_train['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_train['GarageQual'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_test['GarageQual_imputed'][X_test['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['GarageQual_imputed'][X_test['GarageQual_imputed'].isnull()] = X_train['GarageQual'].dropna().sample(X_test['GarageQual'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_train['FireplaceQu_imputed'][X_train['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_train['FireplaceQu'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train['FireplaceQu_imputed'][X_train['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_train['FireplaceQu'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:5: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_test['FireplaceQu_imputed'][X_test['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_test['FireplaceQu'].isnull().sum()).values
# C:\Users\hp\AppData\Local\Temp\ipykernel_33088\856878696.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test['FireplaceQu_imputed'][X_test['FireplaceQu_imputed'].isnull()] = X_train['FireplaceQu'].dropna().sample(X_test['FireplaceQu'].isnull().sum()).values

# %%
temp = pd.concat(
        [
            X_train['GarageQual'].value_counts() / len(X_train['GarageQual'].dropna()),
            X_train['GarageQual_imputed'].value_counts() / len(X_train)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

# %%
temp
# Out:
#     original   imputed
# TA  0.951043  0.950342
# Fa  0.037171  0.036815
# Gd  0.009973  0.011130
# Po  0.000907  0.000856
# Ex  0.000907  0.000856

# %%
temp = pd.concat(
        [
            X_train['FireplaceQu'].value_counts() / len(X_train['FireplaceQu'].dropna()),
            X_train['FireplaceQu_imputed'].value_counts() / len(df)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

temp
# Out:
#     original   imputed
# Gd  0.494272  0.644220
# TA  0.412439  0.544332
# Fa  0.040917  0.052750
# Po  0.027823  0.037037
# Ex  0.024550  0.032548

# %%
for category in X_train['FireplaceQu'].dropna().unique():
    sns.kdeplot(
        X_train[X_train['FireplaceQu'] == category]['SalePrice'],
        label=category
    )

plt.legend()
plt.show()

# %%
for category in X_train['FireplaceQu_imputed'].dropna().unique():
    sns.kdeplot(X_train[X_train['FireplaceQu_imputed'] == category]['SalePrice'],label=category)

plt.legend()
plt.show()
